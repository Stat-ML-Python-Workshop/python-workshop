# %% [markdown]
# # Week 01：環境、package 與 Python 入門
#
# 三次細胞培養量測
#
# 公式：平均 = (a+b+c)/3
#
# 先完成自己的 `basics.py`，再從頭執行。

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from mini_ml.basics import three_measurements
three_measurements()

# %% [markdown]
# ## 與正式版本核對
# 先解釋自己的輸出，再執行下列比較。

# %%
assert np.mean([2,4,6]) == three_measurements()[1]
